# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Commit_Test_Folder/PyTorch_base
# Out:
# /content/drive/MyDrive/Commit_Test_Folder/PyTorch_base

# %%
#!git clone https://kim461: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@github.com/kim461/PyTorch_base.git
# Out:
# fatal: destination path 'PyTorch_base' already exists and is not an empty directory.

# %%
# !git config --global user.email 'dlsrhdwlsmd7@gmail.com'
# !git config --global user.name 'kim461'

# %%
# Out:
# /content/drive/MyDrive/이수안/이수안 머신러닝

# %%
! git add Pytorch_base.ipynb
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
cd /content/drive/MyDrive/Commit_Test_Folder
# Out:
# /content/drive/MyDrive/Commit_Test_Folder

# %%
! git add Pytorch.ipynb
# Out:
# fatal: pathspec 'Pytorch.ipynb' did not match any files

# %%
# !git commit -m '원하는 아무 메시지'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
